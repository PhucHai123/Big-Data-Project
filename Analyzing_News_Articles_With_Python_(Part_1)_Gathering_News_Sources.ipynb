# %% [markdown]
# ## Analyzing News Articles With Python (Part 1)
#
# *By Andre Sealy (Updated 6/21/2020)*
#
# This is the first part of what I believe to be a multi-part series in analyzing news articles on Python.
#
# Never before has America become more polarized than we are today. As such, the news we consume is a function of our polarization. Right-leaning people tend to get their information from Fox News, The Wall Street Journal, National Review, etc. People who lean left tend to get their information from MSNBC, The New York Times, The Huffington Post, etc. There are a handful of neutral publications (Reuters, Politico, Associated Press, etc.). Still, even their alignment falls into question, based on how they report the news.
#
# This project will attempt to analyze how polarizing mainstream articles are for stories typical in the U.S. news cycle, as well as measuring the sentiment for each item. To help guide us for this project, we will be using the website All Sides.
#
# ### All Sides News Aggregator
#
# All Sides is a bipartisan organization that looks at a more balanced approach to news coverage by collecting the top headlines of the day and showcasing the reporting of the news outlet on the left, right, and center. The platform also allows readers the rate the lean of the publication for further analysis.
#
# #### Importing the Modules
#
# Let's begin to load the necessary modules for the project, which include the following:
#
# * **requests**
# * **BeautifulSoup**
# * **csv**
# * **re**
# * **socket**
#
# The `requests` module allows you to send HTTP requests using Python, which will enable you to inspect the structure of many different websites. From there, you will be able to scrape the relevant information of the website with the `BeautifulSoup` module. Regular Expressions or the `re` module allows Python to look for specific text that follows a particular pattern. (doing this technique several times, you'll soon realize that certain outlets follow a pattern when publishing articles)
#
# The `csv` module will just allow us to create and save our information to a csv for further analysis later on. There is nothing reall important about the `socket` module; it's used just in case we run into an error during the extraction process.

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re
import socket

# %% [markdown]
# The first mode of attack is figuring out how we can go about extracting these stories for our analysis. We can extract all stories from all publications, but what if we want a more targeted focus? One interesting feature of the All Sides website is that we can look for articles based on the topic.
#
# ![](https://kidquant.com/post/images/Analyzing-News/topics-allsides.PNG)
#
# We can get articles from pretty much any topic: **Criminal Justice**, **Education**, and the **Economy**. All Sides even collects the news perspectives on the most important topic in the world right now, the Coronavirus. (Yes, our society is so divided right now, we've even managed to politize a deadly virus)
#
# I'm going to use immigration as our topic; I feel it's pretty easy to understand where both sides (the political left and right) stand on this issue.
#
# The following code chunk will extract the most important news stories involving immigration within the last two years.

# %%
# creates a empty list to store the story pages from AllSides.com
pages = []

# We only want to extract stories about immigration
story = 'donald-trump'


def get_seed(n):
    """
    n defines the number of pages back to pull
    n=1 steps back to April 2018 (as of April 2020)
    """

    for i in range(0, n+1):
        url = 'https://www.allsides.com/blog/tags/' + \
            str(story) + '?page=' + str(i)
        pages.append(url)

get_seed(9)

pages
# Out:
# ['https://www.allsides.com/blog/tags/donald-trump?page=0',
#  'https://www.allsides.com/blog/tags/donald-trump?page=1',
#  'https://www.allsides.com/blog/tags/donald-trump?page=2',
#  'https://www.allsides.com/blog/tags/donald-trump?page=3',
#  'https://www.allsides.com/blog/tags/donald-trump?page=4',
#  'https://www.allsides.com/blog/tags/donald-trump?page=5',
#  'https://www.allsides.com/blog/tags/donald-trump?page=6',
#  'https://www.allsides.com/blog/tags/donald-trump?page=7',
#  'https://www.allsides.com/blog/tags/donald-trump?page=8',
#  'https://www.allsides.com/blog/tags/donald-trump?page=9']

# %% [markdown]
# The output should give you a list of page links, which provides a link of stories on the All Sides website.
#
# ![](https://kidquant.com/post/images/Analyzing-News/topics-allsides2.PNG)
#
# We want to create functions that will allow us to parse through the HTML format of the [AllSides](https://www.allsides.com/unbiased-balanced-news) website so we can extract the URLs of these stories. After the extraction process is done, we're going to store all of these links into a list.

# %%
def soup_basic(item):
    # Send a request to the URL and get the response
    response = requests.get(item)

    # Parse the HTML content of the response using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
# set up BeautifulSoup to run over All Sides Media
link_harvest = []

# helper function to harvest and parse pages
def soup_basics(item):
    # Send a request to the URL and get the response
    response = requests.get(item)

    # Parse the HTML content of the response using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    return soup
def harvest_links(pages):
    '''
    runs the parser over submitted pages
    identifies headline link content in the extracted page
    appends relevant links to a list
    '''
    for item in pages:
        soup=soup_basics(item)

        # Find all the links on the page that point to blog posts
        blog_links = []
        for link in soup.find_all('a'):
            href = link.get('href')
            if href and '/blog/' in href:
                blog_links.append(href)

        # Print the list of blog links
        # print(blog_links)
        for i in blog_links:
          if('https://www.allsides.com/' in i) : link = i
          else: link= 'https://www.allsides.com/' +i 
          if not '/tags/' in link:
            link_harvest.append(link)

harvest_links(pages)

# story_headline_list
unique_link_harvest= list(set(link_harvest))
unique_link_harvest
# link_harvest
# Out:
# ['https://www.allsides.com//../blog/rnc-2020-speakers-try-inspire-base-engage-undecided-voters',
#  'https://www.allsides.com//blog/when-donald-trump-gets-back-twitter',
#  'https://www.allsides.com//blog/pro-trump-rally-BLM-protest-odd-couples',
#  'https://www.allsides.com//../blog/coronavirus-reaches-president-trump-and-white-house',
#  'https://www.allsides.com//blog/both-sides-urge-transparency-mar-lago-raid',
#  'https://www.allsides.com//blog/trump%E2%80%99s-economic-plan-other-media-contrasts-week',
#  'https://www.allsides.com//../blog/trump-vs-biden-gun-rights-and-gun-control-explained-two-minutes',
#  'https://www.allsides.com//../blog/trump-vs-biden-education-policy-explained-two-minutes',
#  'https://www.allsides.com//../blog/house-launches-trump-impeachment-inquiry',
#  'https://www.allsides.com//blog/media-bias-alert-what-left-and-right-are-omitting-about-mar-lago-fbi-raid',
#  'https://www.allsides.com//../blog/fact-check-what-does-scotus-travel-ban-ruling-actually-mean',
#  'https://www.allsides.com//blog/story-week-immigrants-crime-and-trumps-comments',
#  'https://www.allsides.com//../blog/fact-check-trumps-star-being-removed-walk-fame',
#  'https://www.allsides.com//blog/trump-v-biden-chinese-foreign-policy',
#  'https://www.allsides.com//../blog/senate-votes-block-trumps-emergency-declaration-0',
#  'https://www.allsides.com//blog/trumps-comments-russian-election-meddling-spark-bipartisan-criticism',
#  'https://www.allsides.com//blog/comey-testifies',
#  'https://www.allsides.com//blog/trump-and-sanders-more-alike-different',
#  'https://www.allsides.com//blog/trumps-war-media',
#  'https://www.allsides.com//../blog/pandemic-and-polarization-increase-need-civility',
#  'https://www.allsides.com//../blog/tensions-heighten-migrant-caravan-arrives-us-mexico-border',
#  'https://www.allsides.com//blog/president-trump-cancels-summit-north-korea',
#  'https://www.allsides.com//blog/when-or-whether-gop-splits-over-trump',
#  'https://www.allsides.com//blog/trump-pulls-america-out-climate-deal',
#  'https://www.allsides.com//blog/trumps-budget-plan',
#  'https://www.allsides.com//blog/facts-vs-myths-did-pro-trump-mob-beat-cop-death',
#  'https://www.allsides.com//../blog/story-week-mueller-speaks-out-about-russia-investigation',
#  'https://www.allsides.com//../blog/media-bias-alert-minimal-coverage-foster-care-executive-order',
#  'https://www.allsides.com//blog/rex-tillerson-fired-secretary-state',
#  'https://www.allsides.com//../blog/russia-friend-or-foe',
#  'https://www.allsides.com//blog/story-week-gop-convention',
#  'https://www.allsides.com//blog/electoral-college-confirms-joe-bidens-victory',
#  'https://www.allsides.com//blog/media-bias-alert-news-outlets-jump-conclusions-john-durham-probe',
#  'https://www.allsides.com//../blog/debates-defining-racism-follow-white-house-progressives-feud',
#  'https://www.allsides.com//blog/media-bias-case-study-how-stories-are-placed',
#  'https://www.allsides.com//../blog/fact-check-does-trump-or-obama-deserve-credit-economy',
#  'https://www.allsides.com//blog/final-days-election-2016',
#  'https://www.allsides.com//../blog/electoral-college-confirms-joe-bidens-victory',
#  'https://www.allsides.com//blog/capitol-breachs-vast-repercussions',
#  'https://www.allsides.com//../blog/tensions-escalate-iran-opinions-diverge-invervention',
#  'https://www.allsides.com//../blog/story-week-trump-pulls-out-debate',
#  'https://www.allsides.com//../blog/trump-vs-biden-healthcare-explained-2-minutes',
#  'https://www.allsides.com//../blog/story-week-immigrants-crime-and-trumps-comments',
#  'https://www.allsides.com//blog/tensions-heighten-migrant-caravan-arrives-us-mexico-border',
#  'https://www.allsides.com//blog/trump-vs-biden-big-tech-explained-2-minutes',
#  'https://www.allsides.com//../blog/more-impeachment-articles-possible-against-trump',
#  'https://www.allsides.com//blog/when-there-are-no-more-rabbits-nancy-pelosi-s-hat',
#  'https://www.allsides.com//../blog/no-it-s-not-okay-make-lists-political-opponents',
#  'https://www.allsides.com//../blog/media-react',
#  'https://www.allsides.com//../blog/trump-vs-biden-quick-links-supreme-court',
#  'https://www.allsides.com//../blog/media-bias-alert-news-outlets-jump-conclusions-john-durham-probe',
#  'https://www.allsides.com//blog/roughly-350-newspapers-rebuke-president-trumps-attacks-media-necessary-step-or-futile-exercise',
#  'https://www.allsides.com//blog/one-year-later-reflections-january-6-us-capitol-riot-differ',
#  'https://www.allsides.com//../blog/when-or-if-former-president-gets-indicted',
#  'https://www.allsides.com//../blog/message-joint-congress',
#  'https://www.allsides.com//../blog/when-or-whether-gop-splits-over-trump',
#  'https://www.allsides.com//../blog/real-change-requires-real-voter-turnout',
#  'https://www.allsides.com//../blog/when-mitch-mcconnell-has-decide-gops-fate',
#  'https://www.allsides.com//blog/why-many-left-are-cutting-trump-supporters',
#  'https://www.allsides.com//blog/when-donald-trump-thinks-he-has-been-cancelled',
#  'https://www.allsides.com//../blog/chatgpt-biden-trump-poem-admiring-bias-fact-check-openai',
#  'https://www.allsides.com//blog/when-republicans-and-democrats-live-alternate-universes',
#  'https://www.allsides.com//blog/when-liz-cheney-and-facebook-end-same-side',
#  'https://www.allsides.com//../blog/trump-vs-biden-criminal-justice-policy',
#  'https://www.allsides.com//blog/mueller-report-trump-implicated-or-vindicated',
#  'https://www.allsides.com//blog/fake-news-alert-fact-checking-what-trump-actually-said-about-disinfectant-0',
#  'https://www.allsides.com//../blog/attorney-general-william-barr-under-microscope',
#  'https://www.allsides.com//blog/when-liz-cheney-runs-president',
#  'https://www.allsides.com//../blog/third-debate-election-integrity',
#  'https://www.allsides.com//../blog/when-trump-repays-biden-s-favor',
#  'https://www.allsides.com//blog/chatgpt-biden-trump-poem-admiring-bias-fact-check-openai',
#  'https://www.allsides.com//../blog/tensions-rise-over-syria',
#  'https://www.allsides.com//blog/biden-era-fact-checkers-are-falling-short',
#  'https://www.allsides.com//../blog/president-trump-cancels-summit-north-korea',
#  'https://www.allsides.com//blog/when-we-ignore-warnings-about-democracy-s-future',
#  'https://www.allsides.com//blog/social-media-summit-draws-praise-criticism',
#  'https://www.allsides.com//blog/when-covid-doesn-t-go-away-election',
#  'https://www.allsides.com//blog/pandemic-and-polarization-increase-need-civility',
#  'https://www.allsides.com//../blog/when-donald-trump-thinks-he-has-been-cancelled',
#  'https://www.allsides.com//../blog/family-separation-border-sparks-outrage',
#  'https://www.allsides.com//blog/did-fbi-raid-or-search-mar-lago-major-news-sources-show-inconsistency',
#  'https://www.allsides.com//../blog/when-fox-news-gets-out-foxed',
#  'https://www.allsides.com//../blog/horowitz-testifies-probe-fbis-trump-investigation',
#  'https://www.allsides.com//../blog/how-fact-checkers-are-biased-2020-election',
#  'https://www.allsides.com//blog/when-or-if-former-president-gets-indicted',
#  'https://www.allsides.com//blog/impeachment-moves-senate',
#  'https://www.allsides.com//../blog/don-t-trust-news-media-s-good',
#  'https://www.allsides.com//blog/russia-friend-or-foe',
#  'https://www.allsides.com//../blog/trumps-1st-budget-announced',
#  'https://www.allsides.com//blog/when-country-agrees-losing-candidate',
#  'https://www.allsides.com//blog/trump-increases-tariffs-chinese-goods',
#  'https://www.allsides.com//../blog/when-dick-cheney-becomes-litmus-test',
#  'https://www.allsides.com//../blog/story-week-trump-implosion-or-media-mania',
#  'https://www.allsides.com//blog/here-s-what-trump-and-biden-have-said-about-first-presidential-debate',
#  'https://www.allsides.com//../blog/hunter-biden-steps-down-chinese-company-admits-poor-judgement',
#  'https://www.allsides.com//blog/when-mitch-mcconnell-has-decide-gops-fate',
#  'https://www.allsides.com//../blog/story-week-can-trump-win',
#  'https://www.allsides.com//blog/democrats-take-control-house-nancy-pelosi-assumes-speakership',
#  'https://www.allsides.com//blog/new-york-times-anonymous-op-ed-met-mixed-reviews',
#  'https://www.allsides.com//../blog/testimony-gordon-sondland-talks-ukraine-quid-pro-quo',
#  'https://www.allsides.com//blog/tensions-rise-over-syria',
#  'https://www.allsides.com//blog/story-week-obama-comments-trump-overseas',
#  'https://www.allsides.com//../blog/trumps-first-week',
#  'https://www.allsides.com//../blog/president-trump-nominates-brett-kavanaugh-supreme-court',
#  'https://www.allsides.com//../blog/trump-says-us-will-remain-steadfast-partner-saudi-arabia-foolish-or-strategic',
#  'https://www.allsides.com//../blog/trump-rittenhouse-center-crime-drama-media-coverage',
#  'https://www.allsides.com//../blog/when-covid-doesn-t-go-away-election',
#  'https://www.allsides.com//../blog/trump-sues-cnn-defamation',
#  'https://www.allsides.com//../blog/why-news-outlets-differ-calling-arizona-biden',
#  'https://www.allsides.com//blog/story-week-trump-pulls-out-debate',
#  'https://www.allsides.com//../blog/report-alleges-trump-belittled-fallen-soldiers-military',
#  'https://www.allsides.com//../blog/when-fbi-gives-trump-early-christmas-gift',
#  'https://www.allsides.com//../blog/google-ceo-testifies-capitol-hill-lawmakers-miss-point',
#  'https://www.allsides.com//blog/debates-defining-racism-follow-white-house-progressives-feud',
#  'https://www.allsides.com//blog/fact-check-what-does-scotus-travel-ban-ruling-actually-mean',
#  'https://www.allsides.com//blog/how-fact-checkers-are-biased-2020-election',
#  'https://www.allsides.com//../blog/media-bias-case-study-how-stories-are-placed',
#  'https://www.allsides.com//../blog/trump-vs-biden-big-tech-explained-2-minutes',
#  'https://www.allsides.com//../blog/media-bias-alert-surveillance-video-reveals-details-about-alleged-election-breach-georgia',
#  'https://www.allsides.com//blog/more-impeachment-articles-possible-against-trump',
#  'https://www.allsides.com//../blog/isis-leader-killed-us-raid',
#  'https://www.allsides.com//../blog/manafort-and-cohen-courtroom-drama-how-will-it-impact-president-trump',
#  'https://www.allsides.com//../blog/when-its-finally-time-think-about-third-party',
#  'https://www.allsides.com//blog/lawsuit-against-trump-raises-question-presidents-twitter-account-public-platform',
#  'https://www.allsides.com//blog/when-and-where-biden-and-trump-draw-2024-battle-lines',
#  'https://www.allsides.com//blog/brazil-rest-world-place-blame-amazon-fires',
#  'https://www.allsides.com//../blog/president-trump-acquitted-two-impeachment-charges',
#  'https://www.allsides.com//blog/trump-and-north-korea',
#  'https://www.allsides.com//../blog/why-many-left-are-cutting-trump-supporters',
#  'https://www.allsides.com//../blog/tucker-carlson-spotlight-january-6-footage-dominion-lawsuit',
#  'https://www.allsides.com//blog/trumps-foreign-policy-speech',
#  'https://www.allsides.com//blog/when-trump-worries-out-loud',
#  'https://www.allsides.com//blog/trump-3rd-us-president-be-impeached',
#  'https://www.allsides.com//blog/media-bias-alert-donald-trump-takes-firm-stance-covid-19-vaccine',
#  'https://www.allsides.com//../blog/trump-administration-revokes-cnn-reporters-press-credentials-sparking-debate-over-free-speech',
#  'https://www.allsides.com//blog/illegal-ballot-harvesting-caused-do-over-house-election-north-carolina-what-are-pros-and-cons',
#  'https://www.allsides.com//../blog/taliban-peace-talks-cancelled-after-kabul-attack',
#  'https://www.allsides.com//../blog/jan-6-committee-hearings-begin',
#  'https://www.allsides.com//../blog/capitol-breachs-vast-repercussions',
#  'https://www.allsides.com//blog/us-stays-iran-nuclear-deal-now',
#  'https://www.allsides.com//blog/mail-bombs-sent-prominent-democrats-sparking-debate-around-civility-politics',
#  'https://www.allsides.com//../blog/when-trump-worries-out-loud',
#  'https://www.allsides.com//../blog/michael-cohen-sentenced-three-years-prison-how-will-it-affect-president-trump',
#  'https://www.allsides.com//blog/when-republicans-go-back-their-pre-reagan-roots',
#  'https://www.allsides.com//../blog/protests-charlottesville-and-presidents-reaction',
#  'https://www.allsides.com//blog/don-t-trust-news-media-s-good',
#  'https://www.allsides.com//blog/third-debate-election-integrity',
#  'https://www.allsides.com//../blog/media-bias-alert-what-left-and-right-are-omitting-about-mar-lago-fbi-raid',
#  'https://www.allsides.com//blog/trump-and-democrats-blame-each-other-government-shutdown-drags',
#  'https://www.allsides.com//../blog/when-supreme-court-battle-just-undercard',
#  'https://www.allsides.com//blog/2020-election-results-allsides-live-blog',
#  'https://www.allsides.com//../blog/twitter-and-trump-clash-after-company-adds-warning-tag-his-tweets',
#  'https://www.allsides.com//blog/did-trump-obstruct-justice-mar-lago',
#  'https://www.allsides.com//../blog/media-bias-alert-journalists-pit-biden-trump-document-scandals-against-each-other',
#  'https://www.allsides.com//blog/when-dick-cheney-becomes-litmus-test',
#  'https://www.allsides.com//blog/story-week-heading-contested-convention',
#  'https://www.allsides.com//blog/rnc-2020-speakers-try-inspire-base-engage-undecided-voters',
#  'https://www.allsides.com//blog/media-react',
#  'https://www.allsides.com//blog/president-trump-nominates-brett-kavanaugh-supreme-court',
#  'https://www.allsides.com//blog/odd-couples-muslim-woman-trump-supporter',
#  'https://www.allsides.com//blog/president-trump-accuses-google-bias-against-his-administration',
#  'https://www.allsides.com//blog/impeachment-arguments-and-against-removing-president',
#  'https://www.allsides.com//blog/president-elect-trump',
#  'https://www.allsides.com//../blog/trump-vs-biden-environmental-policy',
#  'https://www.allsides.com//blog/horowitz-testifies-probe-fbis-trump-investigation',
#  'https://www.allsides.com//../blog/did-media-blow-it-mueller-report',
#  'https://www.allsides.com//blog/trump-vs-biden-criminal-justice-policy',
#  'https://www.allsides.com//../blog/democrats-take-control-house-nancy-pelosi-assumes-speakership',
#  'https://www.allsides.com//../blog/when-republicans-go-back-their-pre-reagan-roots',
#  'https://www.allsides.com//../blog/story-week-obama-comments-trump-overseas',
#  'https://www.allsides.com//blog/us-and-canada-reach-new-trade-pact-supersede-nafta',
#  'https://www.allsides.com//blog/when-college-football-games-affect-presidential-election',
#  'https://www.allsides.com//blog/media-bias-alert-fox-news-crops-trump-out-photo-epstein-maxwell',
#  'https://www.allsides.com//blog/trump-odds-puerto-rico',
#  'https://www.allsides.com//../blog/us-and-canada-reach-new-trade-pact-supersede-nafta',
#  'https://www.allsides.com//../blog/trump-odds-puerto-rico',
#  'https://www.allsides.com//../blog/trump-v-biden-chinese-foreign-policy',
#  'https://www.allsides.com//../blog/mueller-report-trump-implicated-or-vindicated',
#  'https://www.allsides.com//blog/when-supreme-court-battle-just-undercard',
#  'https://www.allsides.com//blog/twitter-and-trump-clash-after-company-adds-warning-tag-his-tweets',
#  'https://www.allsides.com//../blog/pro-trump-rally-BLM-protest-odd-couples',
#  'https://www.allsides.com//blog/google-ceo-testifies-capitol-hill-lawmakers-miss-point',
#  'https://www.allsides.com//../blog/brazil-rest-world-place-blame-amazon-fires',
#  'https://www.allsides.com//../blog/2020-election-results-allsides-live-blog',
#  'https://www.allsides.com//blog/manafort-and-cohen-courtroom-drama-how-will-it-impact-president-trump',
#  'https://www.allsides.com//blog/testimony-gordon-sondland-talks-ukraine-quid-pro-quo',
#  'https://www.allsides.com//blog/why-trump-can-win-re-election-and-why-he-can-t',
#  'https://www.allsides.com//../blog/online-news-sites-announce-trump-victory-excitement-or-horror',
#  'https://www.allsides.com//blog/bidens-popularity-falls-2024-speculation-heats',
#  'https://www.allsides.com//blog/message-joint-congress',
#  'https://www.allsides.com//../blog/when-mike-pence-goes-rogue',
#  'https://www.allsides.com//blog/no-it-s-not-okay-make-lists-political-opponents',
#  'https://www.allsides.com//blog/media-bias-alert-spin-and-slant-skew-news-reports-trump-woodward-interviews',
#  'https://www.allsides.com//../blog/biden-era-fact-checkers-are-falling-short',
#  'https://www.allsides.com//../blog/allegations-against-trump',
#  'https://www.allsides.com//../blog/when-donald-trump-gets-back-twitter',
#  'https://www.allsides.com//../blog/remaking-presidency-trump-cabinet',
#  'https://www.allsides.com//blog/fbi-director-comey-fired',
#  'https://www.allsides.com//blog/jan-6-committee-hearings-begin',
#  'https://www.allsides.com//blog/story-week-wrapping-2017',
#  'https://www.allsides.com//../blog/story-week-wrapping-2017',
#  'https://www.allsides.com//blog/when-party-has-balance-between-politics-and-principle',
#  'https://www.allsides.com//blog/did-media-blow-it-mueller-report',
#  'https://www.allsides.com//blog/report-alleges-trump-belittled-fallen-soldiers-military',
#  'https://www.allsides.com//blog/fact-check-what-happening-border',
#  'https://www.allsides.com//../blog/attorney-general-barr-testifies-senate-judiciary-committee',
#  'https://www.allsides.com//blog/story-week-can-trump-win',
#  'https://www.allsides.com//../blog/one-year-later-reflections-january-6-us-capitol-riot-differ',
#  'https://www.allsides.com//../blog/media-bias-alert-fox-news-crops-trump-out-photo-epstein-maxwell',
#  'https://www.allsides.com//../blog/illegal-ballot-harvesting-caused-do-over-house-election-north-carolina-what-are-pros-and-cons',
#  'https://www.allsides.com//../blog/when-we-ignore-warnings-about-democracy-s-future',
#  'https://www.allsides.com//../blog/trump-shift-deportations',
#  'https://www.allsides.com//blog/coverage-parler-ban-highlights-media-bias',
#  'https://www.allsides.com//../blog/trumps-comments-russian-election-meddling-spark-bipartisan-criticism',
#  'https://www.allsides.com//../blog/how-does-media-bias-against-biden-compare-bias-against-trump-journalists-disagree',
#  'https://www.allsides.com//blog/family-separation-border-sparks-outrage',
#  'https://www.allsides.com//../blog/why-trump-can-win-re-election-and-why-he-can-t',
#  'https://www.allsides.com//../blog/roughly-350-newspapers-rebuke-president-trumps-attacks-media-necessary-step-or-futile-exercise',
#  'https://www.allsides.com//../blog/trump-vs-biden-quick-links-lgbtq-policy',
#  'https://www.allsides.com//../blog/collection-op-eds-foragainst-donald-trump-and-joe-biden',
#  'https://www.allsides.com//blog/trump-vs-biden-education-policy-explained-two-minutes',
#  'https://www.allsides.com//../blog/mail-bombs-sent-prominent-democrats-sparking-debate-around-civility-politics',
#  'https://www.allsides.com//../blog/here-s-what-trump-and-biden-have-said-about-first-presidential-debate',
#  'https://www.allsides.com//../blog/trump-and-north-korea',
#  'https://www.allsides.com//../blog/trumps-war-media',
#  'https://www.allsides.com//../blog/media-bias-alert-spin-and-slant-skew-news-reports-trump-woodward-interviews',
#  'https://www.allsides.com//../blog/biden-projected-win-presidency-trump-alleges-fraud',
#  'https://www.allsides.com//blog/whos-winning-2016',
#  'https://www.allsides.com//blog/why-news-outlets-differ-calling-arizona-biden',
#  'https://www.allsides.com//../blog/trump-declare-national-emergency-border-wall',
#  'https://www.allsides.com//blog/project-veritas-cnn-and-ethics-undercover-reporting',
#  'https://www.allsides.com//../blog/fbi-raids-trumps-mar-lago-home',
#  'https://www.allsides.com//../blog/president-elect-trump',
#  'https://www.allsides.com//blog/when-ex-president-overshadows-his-successor',
#  'https://www.allsides.com//../blog/facts-vs-myths-did-pro-trump-mob-beat-cop-death',
#  'https://www.allsides.com//../blog/story-week-heading-contested-convention',
#  'https://www.allsides.com//blog/biden-less-available-media-past-presidents',
#  'https://www.allsides.com//../blog/trump-3rd-us-president-be-impeached',
#  'https://www.allsides.com//../blog/when-liz-cheney-runs-president',
#  'https://www.allsides.com//blog/trump-tweets-reveal-left-and-right-define-racist-very-differently',
#  'https://www.allsides.com//../blog/lawsuit-against-trump-raises-question-presidents-twitter-account-public-platform',
#  'https://www.allsides.com//blog/trump-vs-biden-healthcare-explained-2-minutes',
#  'https://www.allsides.com//blog/biden-projected-win-presidency-trump-alleges-fraud',
#  'https://www.allsides.com//blog/media-bias-donald-trump-2024-presidential-run-announcement',
#  'https://www.allsides.com//../blog/trump-tweets-reveal-left-and-right-define-racist-very-differently',
#  'https://www.allsides.com//../blog/trumps-foreign-policy-speech',
#  'https://www.allsides.com//blog/story-week-4-views-donald-trump',
#  'https://www.allsides.com//blog/story-week-ryan-and-trump-meet',
#  'https://www.allsides.com//../blog/when-ex-president-overshadows-his-successor',
#  'https://www.allsides.com//../blog/balanced-roundup-trump-vs-biden-issue-and-policy-comparisons',
#  'https://www.allsides.com//blog/trump-tax-plan',
#  'https://www.allsides.com//../blog/impeachment-moves-senate',
#  'https://www.allsides.com//../blog/trump-send-more-troops-afghanistan',
#  'https://www.allsides.com//../blog/final-days-election-2016',
#  'https://www.allsides.com//../blog/when-liz-cheney-and-facebook-end-same-side',
#  'https://www.allsides.com//../blog/fbi-director-comey-fired',
#  'https://www.allsides.com//../blog/who-won-hofstra-debate',
#  'https://www.allsides.com//blog/biden-leads-presidential-vote-count-trump-starts-legal-challenges',
#  'https://www.allsides.com//blog/trump-vs-biden-quick-links-immigration',
#  'https://www.allsides.com//../blog/when-republicans-and-democrats-live-alternate-universes',
#  'https://www.allsides.com//../blog/impeachment-arguments-and-against-removing-president',
#  'https://www.allsides.com//../blog/president-trump-and-kim-jong-un-meet-historic-summit',
#  'https://www.allsides.com//../blog/bidens-popularity-falls-2024-speculation-heats',
#  'https://www.allsides.com//../blog/michael-cohen-releases-tape-president-trump-discussing-payment-former-model',
#  'https://www.allsides.com//blog/trumps-1st-budget-announced',
#  'https://www.allsides.com//../blog/odd-couples-muslim-woman-trump-supporter',
#  'https://www.allsides.com//blog/coronavirus-reaches-president-trump-and-white-house',
#  'https://www.allsides.com//../blog/project-veritas-cnn-and-ethics-undercover-reporting',
#  'https://www.allsides.com//../blog/trump-vs-biden-race-relations-explained-2-minutes',
#  'https://www.allsides.com//blog/when-its-finally-time-think-about-third-party',
#  'https://www.allsides.com//../blog/facts-vs-myths-did-donald-trump-tell-people-inject-bleach',
#  'https://www.allsides.com//blog/who-won-hofstra-debate',
#  'https://www.allsides.com//blog/cant-believe-anyone-would-vote-you-know-who-heres-hint-we-being-right',
#  'https://www.allsides.com//blog/story-week-trump-implosion-or-media-mania',
#  'https://www.allsides.com//blog/trumps-second-impeachment-trial-begins',
#  'https://www.allsides.com//blog/supreme-court-hears-daca-case',
#  'https://www.allsides.com//blog/when-trump-repays-biden-s-favor',
#  'https://www.allsides.com//../blog/story-week-4-views-donald-trump',
#  'https://www.allsides.com//blog/facts-vs-myths-did-donald-trump-tell-people-inject-bleach',
#  'https://www.allsides.com//blog/michael-cohen-sentenced-three-years-prison-how-will-it-affect-president-trump',
#  'https://www.allsides.com//../blog/did-fbi-raid-or-search-mar-lago-major-news-sources-show-inconsistency',
#  'https://www.allsides.com//blog/balanced-roundup-trump-vs-biden-issue-and-policy-comparisons',
#  'https://www.allsides.com//../blog/when-2024-campaign-starts-early',
#  'https://www.allsides.com//blog/trump-shift-deportations',
#  'https://www.allsides.com//../blog/whos-winning-2016',
#  'https://www.allsides.com//../blog/when-cracks-appear-republican-wall',
#  'https://www.allsides.com//blog/fbi-raids-trumps-mar-lago-home',
#  'https://www.allsides.com//../blog/biden-less-available-media-past-presidents',
#  'https://www.allsides.com//blog/trump-impose-tariffs-steel-and-aluminum',
#  'https://www.allsides.com//blog/fact-check-trumps-star-being-removed-walk-fame',
#  'https://www.allsides.com//../blog/story-week-congress-confirms-bidens-victory-4-dead-after-capitol-chaos',
#  'https://www.allsides.com//../blog/trump-and-democrats-blame-each-other-government-shutdown-drags',
#  'https://www.allsides.com//../blog/both-sides-urge-transparency-mar-lago-raid',
#  'https://www.allsides.com//blog/attorney-general-barr-testifies-senate-judiciary-committee',
#  'https://www.allsides.com//blog/trump-administration-revokes-cnn-reporters-press-credentials-sparking-debate-over-free-speech',
#  'https://www.allsides.com//blog/negotiations-stall-government-shutdown-poised-become-longest-history',
#  'https://www.allsides.com//blog/government-shutdown-ends-border-wall-negotiations-continue',
#  'https://www.allsides.com//blog/when-fbi-gives-trump-early-christmas-gift',
#  'https://www.allsides.com//blog/when-mike-pence-goes-rogue',
#  'https://www.allsides.com//blog/tucker-carlson-spotlight-january-6-footage-dominion-lawsuit',
#  'https://www.allsides.com//blog/fact-check-does-trump-or-obama-deserve-credit-economy',
#  'https://www.allsides.com//../blog/rex-tillerson-fired-secretary-state',
#  'https://www.allsides.com//../blog/trump-impose-tariffs-steel-and-aluminum',
#  'https://www.allsides.com//blog/michael-cohen-releases-tape-president-trump-discussing-payment-former-model',
#  'https://www.allsides.com//blog/facts-vs-myths-was-2020-election-stolen',
#  'https://www.allsides.com//blog/media-bias-and-word-choice-jan-6-committee-coverage',
#  'https://www.allsides.com//../blog/shootings-new-zealand-mosques-leave-50-dead',
#  'https://www.allsides.com//blog/story-week-congress-confirms-bidens-victory-4-dead-after-capitol-chaos',
#  'https://www.allsides.com//blog/when-fox-news-gets-out-foxed',
#  'https://www.allsides.com//blog/president-trump-acquitted-two-impeachment-charges',
#  'https://www.allsides.com//../blog/ny-times-and-trumps-taxes-first-presidential-debate',
#  'https://www.allsides.com//blog/media-mostly-unison-fact-checking-trump-claim',
#  'https://www.allsides.com//blog/when-united-states-turns-away-world',
#  'https://www.allsides.com//../blog/story-week-frontrunners-win-big',
#  'https://www.allsides.com//blog/shootings-new-zealand-mosques-leave-50-dead',
#  'https://www.allsides.com//../blog/social-media-summit-draws-praise-criticism',
#  'https://www.allsides.com//blog/tensions-escalate-iran-opinions-diverge-invervention',
#  'https://www.allsides.com//../blog/media-bias-and-word-choice-jan-6-committee-coverage',
#  'https://www.allsides.com//../blog/trumps-second-impeachment-trial-begins',
#  'https://www.allsides.com//../blog/trump-vs-biden-quick-links-immigration',
#  'https://www.allsides.com//blog/senate-votes-block-trumps-emergency-declaration-0',
#  'https://www.allsides.com//blog/attorney-general-william-barr-under-microscope',
#  'https://www.allsides.com//blog/trump-vs-biden-gun-rights-and-gun-control-explained-two-minutes',
#  'https://www.allsides.com//../blog/trumps-budget-plan',
#  'https://www.allsides.com//../blog/story-week-trumps-immigration-plan',
#  'https://www.allsides.com//blog/story-week-mueller-speaks-out-about-russia-investigation',
#  'https://www.allsides.com//../blog/trump-increases-tariffs-chinese-goods',
#  'https://www.allsides.com//blog/trump-vs-biden-race-relations-explained-2-minutes',
#  'https://www.allsides.com//../blog/when-president-s-options-start-shrink',
#  'https://www.allsides.com//blog/trumps-first-week',
#  'https://www.allsides.com//blog/when-we-should-pay-attention-iowa',
#  'https://www.allsides.com//../blog/when-party-has-balance-between-politics-and-principle',
#  'https://www.allsides.com//../blog/media-bias-alert-donald-trump-takes-firm-stance-covid-19-vaccine',
#  'https://www.allsides.com//../blog/when-we-should-pay-attention-iowa',
#  'https://www.allsides.com//../blog/facts-vs-myths-was-2020-election-stolen',
#  'https://www.allsides.com//../blog/government-shutdown-ends-border-wall-negotiations-continue',
#  'https://www.allsides.com//../blog/trump-tax-plan',
#  'https://www.allsides.com//blog/ny-times-and-trumps-taxes-first-presidential-debate',
#  'https://www.allsides.com//blog/justice-department-s-dilemma-over-prosecuting-politicians-election',
#  'https://www.allsides.com//../blog/president-trump-accuses-google-bias-against-his-administration',
#  'https://www.allsides.com//../blog/coverage-parler-ban-highlights-media-bias',
#  'https://www.allsides.com//blog/collection-op-eds-foragainst-donald-trump-and-joe-biden',
#  'https://www.allsides.com//../blog/media-bias-donald-trump-2024-presidential-run-announcement',
#  'https://www.allsides.com//../blog/fake-news-alert-fact-checking-what-trump-actually-said-about-disinfectant-0',
#  'https://www.allsides.com//../blog/supreme-court-hears-daca-case',
#  'https://www.allsides.com//../blog/did-trump-obstruct-justice-mar-lago',
#  'https://www.allsides.com//blog/trump-declare-national-emergency-border-wall',
#  'https://www.allsides.com//../blog/cant-believe-anyone-would-vote-you-know-who-heres-hint-we-being-right',
#  'https://www.allsides.com//blog/trump-vs-biden-environmental-policy',
#  'https://www.allsides.com//blog/media-bias-alert-minimal-coverage-foster-care-executive-order',
#  'https://www.allsides.com//blog/story-week-frontrunners-win-big',
#  'https://www.allsides.com//blog/hunter-biden-steps-down-chinese-company-admits-poor-judgement',
#  'https://www.allsides.com//blog/trump-sues-cnn-defamation',
#  'https://www.allsides.com//../blog/trump-indictment-unclear-jury-delays-meetings',
#  'https://www.allsides.com//blog/story-week-trumps-immigration-plan',
#  'https://www.allsides.com//blog/taliban-peace-talks-cancelled-after-kabul-attack',
#  'https://www.allsides.com//blog/when-cracks-appear-republican-wall',
#  'https://www.allsides.com//blog/isis-leader-killed-us-raid',
#  'https://www.allsides.com//blog/trump-send-more-troops-afghanistan',
#  'https://www.allsides.com//blog/remaking-presidency-trump-cabinet',
#  'https://www.allsides.com//blog/allegations-against-trump',
#  'https://www.allsides.com//../blog/trump-and-sanders-more-alike-different',
#  'https://www.allsides.com//blog/trump-says-us-will-remain-steadfast-partner-saudi-arabia-foolish-or-strategic',
#  'https://www.allsides.com//../blog/justice-department-s-dilemma-over-prosecuting-politicians-election',
#  'https://www.allsides.com//blog/real-change-requires-real-voter-turnout',
#  'https://www.allsides.com//../blog/trump%25E2%2580%2599s-economic-plan-other-media-contrasts-week',
#  'https://www.allsides.com//blog/online-news-sites-announce-trump-victory-excitement-or-horror',
#  'https://www.allsides.com//../blog/when-and-where-biden-and-trump-draw-2024-battle-lines',
#  'https://www.allsides.com//../blog/negotiations-stall-government-shutdown-poised-become-longest-history',
#  'https://www.allsides.com//../blog/when-there-are-no-more-rabbits-nancy-pelosi-s-hat',
#  'https://www.allsides.com//blog/has-age-trump-artificially-moved-media-bias-ratings-left',
#  'https://www.allsides.com//blog/media-bias-alert-surveillance-video-reveals-details-about-alleged-election-breach-georgia',
#  'https://www.allsides.com//../blog/biden-leads-presidential-vote-count-trump-starts-legal-challenges',
#  'https://www.allsides.com//blog/protests-charlottesville-and-presidents-reaction',
#  'https://www.allsides.com//blog/trump-rittenhouse-center-crime-drama-media-coverage',
#  'https://www.allsides.com//../blog/story-week-gop-convention',
#  'https://www.allsides.com//blog/media-bias-alert-journalists-pit-biden-trump-document-scandals-against-each-other',
#  'https://www.allsides.com//../blog/when-united-states-turns-away-world',
#  'https://www.allsides.com//../blog/fact-check-what-happening-border',
#  'https://www.allsides.com//blog/house-launches-trump-impeachment-inquiry',
#  'https://www.allsides.com//../blog/us-stays-iran-nuclear-deal-now',
#  'https://www.allsides.com//../blog/when-country-agrees-losing-candidate',
#  'https://www.allsides.com//blog/federal-judge-rules-obamacare-unconstitutional-political-blunder-or-right-turn',
#  'https://www.allsides.com//../blog/trump-pulls-america-out-climate-deal',
#  'https://www.allsides.com//../blog/media-mostly-unison-fact-checking-trump-claim',
#  'https://www.allsides.com//blog/trump-vs-biden-quick-links-supreme-court',
#  'https://www.allsides.com//../blog/federal-judge-rules-obamacare-unconstitutional-political-blunder-or-right-turn',
#  'https://www.allsides.com//../blog/comey-testifies',
#  'https://www.allsides.com//../blog/has-age-trump-artificially-moved-media-bias-ratings-left',
#  'https://www.allsides.com//blog/trump-vs-biden-quick-links-lgbtq-policy',
#  'https://www.allsides.com//../blog/story-week-ryan-and-trump-meet',
#  'https://www.allsides.com//blog/president-trump-and-kim-jong-un-meet-historic-summit',
#  'https://www.allsides.com//../blog/new-york-times-anonymous-op-ed-met-mixed-reviews',
#  'https://www.allsides.com//blog/trump-indictment-unclear-jury-delays-meetings',
#  'https://www.allsides.com//blog/how-does-media-bias-against-biden-compare-bias-against-trump-journalists-disagree',
#  'https://www.allsides.com//../blog/when-college-football-games-affect-presidential-election',
#  'https://www.allsides.com//blog/when-2024-campaign-starts-early',
#  'https://www.allsides.com//blog/when-president-s-options-start-shrink']

# %% [markdown]
# The following output shows an example of 10 links to AllSide stories on immigration. Now we want to extract the URLs to the articles from the following stories. The links can be found as follows:
#
# ![](https://kidquant.com/post/images/Analyzing-News/topics-allsides3.PNG)
#
# We want to be able to locate the href tag that contains the link to the article. We can do this using the `BeautifulSoup` module I mentioned earlier.
#
# ![](https://kidquant.com/post/images/Analyzing-News/topics-allsides4.PNG)
#
# If we expect the elements of the AllSides webpage, we review the HTML and CSS structure of the webpage. The link to the Reuters article is wrapped around an href container. We use the `soup.find_all` method to locate the title and the URL containers.
#
# Once we have located the containers, we can extract the information inside; namely the Title and the URL.

# %% [markdown]
# Now that we've extracted all of the necessary articles, we want to be able to save these articles for research later on. The following chunk will allow us to keep all of the links into a single text file.

# %% [markdown]
# Finally, we want to create a function that allows us to extract the important information for the articles we're planning on extracting. This information includes the following: **Date**, **Headline**, **Story Description**, **Source/Publication**, **Bias/Lean**, and **Link**.
#
# We're going to be using the same technique to extract this information, as we did with the article URLs. However, the only difference is that this information is located in HTML class attributes. As long as we are aware of the exact attributes, we can extract the relevant information.
#
# Afterward, we will review the results of the function by using `pandas` to open the CSV file.

# %%
def find_bias(st):
  substory_bias=None
  lst=['Left','Right','Center','Lean Left','Lean Right']
  for i in lst:
    if(i in str(st)) : substory_bias=i
  return substory_bias

# %% [markdown]
# find bias ............................

# %%
# get all news article links
all_articles = []


def extract_articles(link):
    for link_content in link:
        soup = soup_basics(link_content)

        # locate relevant information within the extracted page
        substory_list = soup.find_all(class_='blog-content-wrapper')

        # loop through the different news sources within each major news story
        if 'Snippets ' in str(substory_list) :
          for i in range(0, len(substory_list)):
              substory_items = substory_list[i].find_all('a')
              for substory_headline in substory_items:
                  link = substory_headline.get('href')
                  if link and '/news/20' in link:
                    all_articles.append(link)

extract_articles(unique_link_harvest)
unique_all_articles= list(set(all_articles))
unique_all_articles
unique_all_articles[0:99]
# Out:
# ['https://www.allsides.com/news/2019-12-26-0602/house-democrats-are-contemplating-adding-new-articles-impeachment',
#  'https://www.allsides.com/news/2019-11-21-0734/trump-says-its-all-over-impeachment-inquiry-after-sondland-testimony',
#  'https://www.allsides.com/news/2019-02-14-1633/trumps-emergency-declaration-would-trigger-drawn-out-legal-fight?utm_source=newsletter&utm_medium=Story&utm_campaign=USATODAYTrumpsEmergencyDeclarationWouldTriggerDrawnOutLegalFight&utm_source=AllSides+Mailing+List&utm_campaign=f8edc1488d-National_Emergency_Border_Wall_02142019&utm_medium=email&utm_term=0_0b086ce741-f8edc1488d-',
#  'http://www.allsides.com/news/2016-10-12-0731/politics-us-climate-change?utm_source=AllSides+Mailing+List&utm_campaign=d946eaa764-Allegations_Against_Trump_1013016&utm_medium=email&utm_term=0_0b086ce741-d946eaa764-',
#  'https://www.allsides.com/news/2019-09-11-1423/why-donald-trumps-plan-host-taliban-prestigious-camp-david-stirred-bipartisan',
#  'https://www.allsides.com/news/2020-01-16-0722/impeachment-trap-endangered-senate-republicans-face-peril-whether-they-support',
#  'http://www.allsides.com/news/2016-10-13-0833/trump-reels-more-accusers-emerge?utm_source=AllSides+Mailing+List&utm_campaign=d946eaa764-Allegations_Against_Trump_1013016&utm_medium=email&utm_term=0_0b086ce741-d946eaa764-',
#  'https://www.allsides.com/news/2019-03-21-1316/new-zealand-showing-america-how-respond-mass-shootings?utm_source=newsletter&utm_medium=Story&utm_campaign=WaPoNewZealandShowingAmericaRespondMassShootings&utm_source=AllSides+Mailing+List&utm_campaign=b465b10880-Shooting_NZ_Mosque_03212019&utm_medium=email&utm_term=0_0b086ce741-b465b10880-',
#  'https://www.allsides.com/news/2018-07-19-1511/helsinki-trump-shows-he-indeed-guilty-collusion?utm_source=newsletter&utm_medium=Story&utm_campaign=MotherJonesGuiltyofCollusion&utm_source=AllSides+Mailing+List&utm_campaign=ce3f1d982a-Democratic_Memo_Released_03012018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-ce3f1d982a-',
#  'https://www.allsides.com/news/2019-05-10-0717/no-cheating-friends?utm_source=newsletter&utm_medium=Story&utm_campaign=WashTimesNoCheatingFriends&utm_source=AllSides+Mailing+List&utm_campaign=d641d2cf9b-Barr_Testifies_Senate_05022019_COPY_01&utm_medium=email&utm_term=0_0b086ce741-d641d2cf9b-',
#  'https://www.allsides.com/news/2020-01-16-0718/gop-senator-2020-candidates-must-recuse-themselves-impeachment-trial',
#  'https://www.allsides.com/news/2018-07-12-1251/brett-kavanaugh-trump%E2%80%99s-supreme-court-pick-probably-end-abortion-rights-and?utm_source=newsletter&utm_medium=Story&utm_campaign=KavanaughAbortionDailyBeast&utm_source=AllSides+Mailing+List&utm_campaign=748bc307cb-Democratic_Memo_Released_03012018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-748bc307cb-',
#  'https://www.allsides.com/news/2020-02-20-0954/furor-over-trump-pardons-frustrated-barr-weighs-quitting',
#  'https://www.allsides.com/news/2019-01-31-1619/trump-says-he-willing-move-without-congress-border-wall?utm_source=newsletter&utm_medium=Story&utm_campaign=WSJTrumpWillingToMoveWithoutCongressBorderWall&utm_source=AllSides+Mailing+List&utm_campaign=7b77a27c67-Shutdown_Ends_Wall_Negotiations_Continue_01312019&utm_medium=email&utm_term=0_0b086ce741-7b77a27c67-',
#  'https://www.allsides.com/news/2020-01-16-0707/pelosi-hands-out-souvenir-pens-dems-slammed-gloating-house-delivers-trump',
#  'https://www.allsides.com/news/2019-03-28-1419/mueller-report-heres-what-we-know-and-still-dont-know-and-may-never-know?utm_source=newsletter&utm_medium=Story&utm_campaign=USATODAYMuellerReportKnowAndDontKnow',
#  'https://www.allsides.com/news/2021-01-13-1223/majority-back-impeachment-and-are-concerned-about-more-dc-violence-cbs-news',
#  'https://www.allsides.com/news/2018-10-04-1415/victory-trade?utm_source=newsletter&utm_medium=Story&utm_campaign=TownhallVictoryTrade&utm_source=AllSides+Mailing+List&utm_campaign=9238093118-US_Canada_New_Trade_Deal_10042018&utm_medium=email&utm_term=0_0b086ce741-9238093118-',
#  'https://www.allsides.com/news/2022-09-01-0757/us-justice-dept-face-against-trump-legal-team-over-seized-records',
#  'https://www.allsides.com/news/2022-01-06-0616/five-enduring-lies-about-capitol-insurrection',
#  "https://www.allsides.com/news/2019-07-12-0603/trump's-'social-media-summit'-airs-grievances-against-big-tech?utm_content=WSJBigTechSummit",
#  'https://www.allsides.com/news/2021-01-13-1425/house-impeaches-president-trump-second-time',
#  'https://www.allsides.com/news/2023-03-08-1638/media-industry-republicans-no-longer-fear-tucker-carlson',
#  'https://www.allsides.com/news/2020-05-28-0702/trump-preparing-order-targeting-social-media-protections',
#  'http://www.allsides.com/news/2016-11-01-1153/white-house-defends-fbi-director-comey%E2%80%99s-integrity?utm_source=AllSides+Mailing+List&utm_campaign=ca07c0b97e-The_Final_Days_Election_2016_11032016&utm_medium=email&utm_term=0_0b086ce741-ca07c0b97e-',
#  'https://www.allsides.com/news/2019-09-11-1439/trump-canceled-his-secret-meeting-taliban-negotiations-were-trouble-anyway',
#  'https://www.allsides.com/news/2020-01-30-0757/john-bolton-wrote-his-memoir-trump-did-very-thing-he-s-been-impeached-trial',
#  'https://www.allsides.com/news/2020-11-05-0700/biden-may-steal-election-elitists-democrats-will-regret-it-devine',
#  'https://www.allsides.com/news/2019-12-26-0605/house-says-it-needs-don-mcgahns-testimony-senate-trial-and-because-trump-could',
#  'https://www.allsides.com/news/2018-10-04-1408/trump-aims-model-new-trade-deals-revised-nafta?utm_source=newsletter&utm_medium=Story&utm_campaign=WSJTrumpAimsModelNewTradeDealsRevisedNafta&utm_source=AllSides+Mailing+List&utm_campaign=9238093118-US_Canada_New_Trade_Deal_10042018&utm_medium=email&utm_term=0_0b086ce741-9238093118-',
#  'https://www.allsides.com/news/2020-09-08-1214/3-crucial-breakdowns-journalistic-standards-explain-atlantic-s-trump-political',
#  'https://www.allsides.com/news/2022-01-04-0819/corporate-media-s-jan-6-anniversary-coverage-all-about-silencing-republicans',
#  'https://www.allsides.com/news/2019-04-18-0918/mueller-report-documents-links-between-trump-campaign-and-russia-steps-thwart?utm_source=newsletter&utm_medium=Story&utm_campaign=USATODAYMuellerReportTrumpCampaignRussia&utm_source=AllSides+Mailing+List&utm_campaign=b4050249de-Mueller_Report_Trump_04182019&utm_medium=email&utm_term=0_0b086ce741-b4050249de-',
#  'https://www.allsides.com/news/2019-07-19-1006/just-say-racist?utm_content=RacismCJRStory',
#  'https://www.allsides.com/news/2019-09-11-1418/trump-peace-talks-taliban-dead-after-attack-kills-american-soldier',
#  'https://www.allsides.com/news/2020-02-20-1012/what-would-make-william-barr-quit',
#  'https://www.allsides.com/news/2019-07-19-0728/race-card-has-gone-bust?utm_content=RaceCardBustWSJStory',
#  'http://www.allsides.com/news/2017-10-19-1550/netanyahu%E2%80%99s-challenge-help-trump-fix-or-scrap-iran-deal?utm_source=AllSides+Mailing+List&utm_campaign=e64f4c67a4-Iran_Nuclear_Deal_10192017&utm_medium=email&utm_term=0_0b086ce741-e64f4c67a4-',
#  'https://www.allsides.com/news/2018-06-21-1443/trump-administration-lying-about-its-family-separation-policy?utm_source=AllSides+Mailing+List&utm_campaign=a17e881837-Democratic_Memo_Released_03012018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-a17e881837-',
#  'http://www.allsides.com/news/2016-05-26-1559/obama-trump-more-interested-%E2%80%98tweets-and-headlines%E2%80%99-keeping-america-safe?utm_source=AllSides+Mailing+List&utm_campaign=c4f7adac00-Obama_Comments_on_Trump_Overseas_05262016&utm_medium=email&utm_term=0_0b086ce741-c4f7adac00-',
#  'https://www.allsides.com/news/2020-11-09-1910/barr-tells-federal-prosecutors-investigate-clear-instances-voting',
#  'https://www.allsides.com/news/2020-11-04-2150/election-reveals-deeper-divides-between-red-and-blue-america',
#  'https://www.allsides.com/news/2023-03-23-0604/donald-trump-trump-s-risky-call-protests',
#  'https://www.allsides.com/news/2019-10-31-0739/us-recovered-valuable-intelligence-baghdadi-raid',
#  'https://www.allsides.com/news/2019-11-14-0636/don-t-count-senate-save-dreamers-scotus',
#  'https://www.allsides.com/news/2021-01-11-1946/trump-twitter-republicans-and-democrats-split-over-freedom-speech',
#  'https://www.allsides.com/news/2018-12-14-1228/former-trump-lawyer-michael-cohen-sentenced-three-years-prison?utm_source=newsletter&utm_medium=Story&utm_campaign=ReutersTrumpLawyerCohenSentencedThreeYearsPrison&utm_source=AllSides+Mailing+List&utm_campaign=f6b7984de1-Michael_Cohen_Sentenced_12142018&utm_medium=email&utm_term=0_0b086ce741-f6b7984de1-',
#  'https://www.allsides.com/news/2019-07-19-0719/trump-squad-and-standard-definition-racism?utm_content=TrumpRacistSquadNYStory',
#  'https://www.allsides.com/news/2019-09-11-1445/game-after-trump-declares-peace-talks-dead-us-commander-takes-aim-taliban',
#  'http://www.allsides.com/news/2016-10-31-0703/fbi-drama-injects-uncertainty-frantic-final-week-race?utm_source=AllSides+Mailing+List&utm_campaign=ca07c0b97e-The_Final_Days_Election_2016_11032016&utm_medium=email&utm_term=0_0b086ce741-ca07c0b97e-',
#  'http://www.allsides.com/news/2016-11-02-1022/politics-us-bridging-divides?utm_source=AllSides+Mailing+List&utm_campaign=ca07c0b97e-The_Final_Days_Election_2016_11032016&utm_medium=email&utm_term=0_0b086ce741-ca07c0b97e-',
#  'https://www.allsides.com/news/2020-02-20-1024/hollywood-demands-ag-bill-barr-resign-restore-public-confidence-doj',
#  'https://www.allsides.com/news/2022-06-09-0604/jan-6-panel-holds-prime-time-televised-hearing-bid-imprint-implications',
#  'http://www.allsides.com/news/2016-10-19-0647/politics-us-illegal-immigration?utm_source=AllSides+Mailing+List&utm_campaign=70c72c3c31-Third_Debate_Election_Integrity_1020016&utm_medium=email&utm_term=0_0b086ce741-70c72c3c31-',
#  'https://www.allsides.com/news/2018-08-23-1209/manafort%E2%80%99s-verdict-and-cohen%E2%80%99s-plea-gave-trump-his-worst-day-russia?utm_source=newsletter&utm_medium=Story&utm_campaign=WaPoWorstDayRussiaInvestigation&utm_source=AllSides+Mailing+List&utm_campaign=736fd88266-Trump_Cohen_Tapes_07262018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-736fd88266-',
#  'https://www.allsides.com/news/2019-02-14-1753/we-have-national-emergency-all-right-its-name-donald-trump?utm_source=newsletter&utm_medium=Story&utm_campaign=WaPoWeHaveANationalEmergencyDonaldTrump&utm_source=AllSides+Mailing+List&utm_campaign=f8edc1488d-National_Emergency_Border_Wall_02142019&utm_medium=email&utm_term=0_0b086ce741-f8edc1488d-',
#  'https://www.allsides.com/news/2019-12-26-0606/could-democrats-impeach-trump-twice-they-might-have',
#  'https://www.allsides.com/news/2019-11-14-0634/why-daca-legal',
#  'https://www.allsides.com/news/2020-12-16-1106/electoral-college-flawed-so-are-alternatives',
#  'https://www.allsides.com/news/2021-02-09-0726/trumps-lawyers-warn-republican-retaliation-impeachment-political-weapon',
#  'https://www.allsides.com/news/2019-09-11-1408/walking-away-taliban-deal-trump-showed-wisdom-obama-never-had',
#  'https://www.allsides.com/news/2018-10-04-1416/trump%E2%80%99s-%E2%80%98new%E2%80%99-canada-mexico-trade-deal-has-all-kinds-improvements-thanks-obama?utm_source=newsletter&utm_medium=Story&utm_campaign=HuffPostNewTradeDealThanksObama&utm_source=AllSides+Mailing+List&utm_campaign=9238093118-US_Canada_New_Trade_Deal_10042018&utm_medium=email&utm_term=0_0b086ce741-9238093118-',
#  'https://www.allsides.com/news/2019-09-25-0835/transcript-trumps-call-ukraine-shows-no-link-military-aid-refuting-democrats',
#  'https://www.allsides.com/news/2018-08-30-0633/trump-warns-google-facebook-and-twitter-row-over-bias?utm_source=newsletter&utm_medium=Story&utm_campaign=BBCTrumpWarnsGoogleRowOverBias',
#  'https://www.allsides.com/news/2020-02-20-0949/fall-doj',
#  'https://www.allsides.com/news/2019-10-17-0614/trump-s-claims-about-hunter-biden-china',
#  'https://www.allsides.com/news/2020-10-01-0721/factchecking-first-trump-biden-debate',
#  'https://www.allsides.com/news/2019-02-14-1739/pelosi-warns-future-democratic-president-could-declare-national-emergency-push?utm_source=newsletter&utm_medium=Story&utm_campaign=DailyCallerPelosiCouldDeclareEmergencyPushGunControl&utm_source=AllSides+Mailing+List&utm_campaign=f8edc1488d-National_Emergency_Border_Wall_02142019&utm_medium=email&utm_term=0_0b086ce741-f8edc1488d-',
#  'https://www.allsides.com/news/2022-10-06-0728/justice-trump-wants-cnn-prove-big-lie-475-million-defamation-case-against',
#  'https://www.allsides.com/news/2019-12-12-0646/five-takeaways-horowitzs-testimony-capitol-hill',
#  'https://www.allsides.com/news/2018-07-12-1254/trump-picks-conservative-judge-kavanaugh-supreme-court?utm_source=newsletter&utm_medium=Story&utm_campaign=KavanaughNominationReuters&utm_source=AllSides+Mailing+List&utm_campaign=748bc307cb-Democratic_Memo_Released_03012018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-748bc307cb-',
#  'https://www.allsides.com/news/2020-09-30-1228/reliable-polls-show-biden-won-debate-so-those-aren-t-what-trump-s-allies-are',
#  'https://www.allsides.com/news/2018-11-15-1325/trump-was-right-boot-cnns-jim-acosta-out-white-house?utm_source=newsletter&utm_medium=Story&utm_campaign=WashTimesTrumpRightToBootJimAcostaWhiteHouse&utm_source=AllSides+Mailing+List&utm_campaign=4c237b4073-Trump_Revokes_Reporter_Press_Credentials_11152018&utm_medium=email&utm_term=0_0b086ce741-4c237b4073-',
#  'https://www.allsides.com/news/2020-02-20-0958/trump-takes-call-barr-clean-house-justice-dept',
#  'https://www.allsides.com/news/2021-02-10-2108/trial-highlights-gop-rift-kinzinger-criticizes-hawley',
#  'https://www.allsides.com/news/2019-12-19-0549/pelosi-threatens-delay-senate-impeachment-trial',
#  'https://www.allsides.com/news/2019-11-14-0636/data-daca-and-crime',
#  'https://www.allsides.com/news/2019-01-31-1614/shutdown-was-proof-trump%E2%80%99s-stark-incapacity-leadership?utm_source=newsletter&utm_medium=Story&utm_campaign=WaPoShutdownProofTrumpsIncapacityForLeadership',
#  'https://www.allsides.com/news/2019-12-12-0653/doj-watchdog-tells-senate-he-has-deep-concerns-about-fbi-errors-russia-probe',
#  'https://www.allsides.com/news/2019-03-21-1302/when-media-makes-trump-target?utm_source=newsletter&utm_medium=Story&utm_campaign=WashTimesMediaTrumpTarget&utm_source=AllSides+Mailing+List&utm_campaign=b465b10880-Shooting_NZ_Mosque_03212019&utm_medium=email&utm_term=0_0b086ce741-b465b10880-',
#  'https://www.allsides.com/news/2020-02-06-0715/after-senate-acquittal-trump-tweets-video-showing-him-running-president',
#  'http://www.allsides.com/news/2017-03-01-0722/trump-seeks-parlay-post-speech-boost-action-contentious-agenda?utm_source=AllSides+Mailing+List&utm_campaign=e58c1726ff-Message_to_Joint_Congress_03022017&utm_medium=email&utm_term=0_0b086ce741-e58c1726ff-&mc_cid=e58c1726ff&mc_eid=%5BUNIQID%5D',
#  'https://www.allsides.com/news/2020-01-30-0640/trump-legal-team-advances-blanket-defense-against-impeachment',
#  'https://www.allsides.com/news/2018-07-21-0855/michael-cohens-tape-trump-isnt-big-deal-%E2%80%93-yet?utm_source=newsletter&utm_medium=Story&utm_campaign=DCExaminerTapesNotBigDealYet&utm_source=AllSides+Mailing+List&utm_campaign=2af41ca06a-Trump_Cohen_Tapes_07262018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-2af41ca06a-',
#  'http://www.allsides.com/news/2018-06-14-1423/trump-says-summit-removed-north-korean-nuclear-threat-democrats-doubtful?utm_source=AllSides+Mailing+List&utm_campaign=041c4d0a92-Democratic_Memo_Released_03012018_COPY_01&utm_medium=email&utm_term=0_0b086ce741-041c4d0a92-',
#  'https://www.allsides.com/news/2019-12-12-0652/michael-horowitz-just-shot-down-bunch-trump-conspiracy-theories',
#  'https://www.allsides.com/news/2020-02-06-0719/law-suckers',
#  'http://www.allsides.com/news/2016-08-11-1528/clinton-dismiss-trumps-economic-plan-friends-and-family-discount?utm_source=AllSides+Mailing+List&utm_campaign=3d5d7a8c3d-Trump_Economic_Plan_08112016&utm_medium=email&utm_term=0_0b086ce741-3d5d7a8c3d-',
#  'http://www.allsides.com/news/2017-04-11-0812/tillerson-arrives-moscow-tensions-rise-over-syria?utm_source=AllSides+Mailing+List&utm_campaign=c8c67dedef-Tensions_Rise_Over_Syria_04132017&utm_medium=email&utm_term=0_0b086ce741-c8c67dedef-&mc_cid=c8c67dedef&mc_eid=%5BUNIQID%5D',
#  'https://www.allsides.com/news/2020-01-16-0713/rudy-giuliani-s-indicted-associate-says-trump-knew-exactly-what-was-going',
#  'http://allsides.com/news/2016-03-17-1633/conservatives-pin-hopes-convention-fight-stop-donald-trump',
#  'https://www.allsides.com/news/2021-01-14-0722/twitter-ceo-jack-dorsey-we-set-dangerous-precedent-banning-trump',
#  'https://www.allsides.com/news/2020-01-27-1526/follow-money-impeachment-trump-bought-jury-and-hints-bigger-tax-cuts',
#  'https://www.allsides.com/news/2019-05-10-0706/us-consumers-and-businesses-not-china-bear-brunt-trumps-tariffs?utm_source=newsletter&utm_medium=Story&utm_campaign=CBSUSConsumersBusinessesBearBruntTariffs&utm_source=AllSides+Mailing+List&utm_campaign=d641d2cf9b-Barr_Testifies_Senate_05022019_COPY_01&utm_medium=email&utm_term=0_0b086ce741-d641d2cf9b-',
#  'https://www.allsides.com/news/2021-07-07-1017/trump-sue-facebook-twitter-google-over-alleged-censorship-says-theyve-ceased-be',
#  'https://www.allsides.com/news/2021-01-07-0604/capitol-riot-will-hurt-people-who-were-already-hurting-most',
#  'https://www.allsides.com/news/2022-08-11-0743/fbi-director-condemns-threats-agents-after-raid-trumps-mar-lago',
#  'https://www.allsides.com/news/2019-08-28-1833/amazon-rainforest-fire-how-spot-inaccurate-photos-social-media',
#  'https://www.allsides.com/news/2020-01-15-1834/how-senate-impeachment-trial-works']

# %%
import pandas as pd

socket.socket

def csv_encoder(text_string):
    coded = text_string.encode("utf-8").strip()
    return coded

# extract all content
def extract_content(link_harvest):
    '''
    for each story, pulls the shared news headline, date, and summary description
    for each news source, identifies the source bias (liberal, conservative, center) & outgoing link
    uses re and .contents to clean harvested text
    writes collected, cleaned data to csv
    '''

    # open csv file to store info
    file = open('allsides-content-f.csv', 'w+', newline="", encoding='utf-8')
    fileWriter = csv.writer(file)
    fileWriter.writerow(['Date', 'Description',
                         'Source_Name', 'Source_Bias', 'Source_Headline', 'Source_Link'])

    try:
        for i in range(len(unique_all_articles)):
            soup = soup_basics(unique_all_articles[i])


            story_date = soup.find(property="og:updated_time")
            parts = str(story_date).split('"')
            if len(parts)>1 :
              clean_date = parts[1]
            else:
              clean_date = None
            clean_date


            lst_line=[]
            lines = str(soup).split("\n")
            for line in lines:
              if 'description' in line : 
                lst_line.append(line)
            try:
                    if len(lst_line[0].split('"'))>2:
                        if 'og:description' in lst_line[0].split('"') : clean_description=lst_line[0].split('"')[0]
                        else :  clean_description=lst_line[0].split('"')[1]
            except: continue

            substory_source = soup.find(property='og:url')
            parts = str(substory_source).split('"')
            if len(parts) >1 :
              clean_source = parts[1]
            else:
              clean_source = None
            clean_source

            soup = soup_basic(all_articles[i])
            lst_line=[]
            lines = str(soup).split("\n")
            for line in lines:
              if 'field-content">From The' in line : 
                lst_line.append(line)
            clean_bias = find_bias(lst_line)
            clean_bias


            substory_list = soup.find(property='og:title')
            parts = str(substory_list).split('"')
            if len(parts) >1 :
              clean_list = parts[1]
            else:
              clean_list = None
            
            
            fileWriter.writerow(
                [clean_date, clean_description,clean_list , clean_bias, clean_source, unique_all_articles[i]])

    except socket.error as err:
        print('Socket connection error... Waiting 10 seconds to retry.')
        del self.sock
        time.sleep(10)
        try_count += 1

    file.close()

# running the function
extract_content(unique_all_articles)

# showing the results of the csv
pd.read_csv('allsides-content-f.csv').head(45)
# Out:
#                          Date  \
# 0   2019-12-26T06:02:18-08:00
# 1   2019-11-21T07:34:08-08:00
# 2   2019-02-14T16:37:59-08:00
# 3   2016-10-12T07:31:05-07:00
# 4   2019-09-11T14:23:57-07:00
# 5   2020-01-16T07:22:14-08:00
# 6   2019-08-21T08:12:02-07:00
# 7   2019-03-21T13:16:59-07:00
# 8   2018-07-19T15:11:57-07:00
# 9   2019-05-10T07:17:07-07:00
# 10  2020-01-16T07:18:56-08:00
# 11  2018-07-12T12:51:22-07:00
# 12  2022-05-12T01:54:56-07:00
# 13  2019-01-31T16:19:18-08:00
# 14  2020-01-16T07:07:51-08:00
# 15  2019-03-28T14:19:22-07:00
# 16  2021-01-13T12:23:52-08:00
# 17  2018-10-04T14:15:38-07:00
# 18  2022-09-01T07:57:49-07:00
# 19  2022-07-20T12:44:42-07:00
# 20  2019-07-12T09:59:03-07:00
# 21  2021-01-13T14:25:51-08:00
# 22  2023-03-08T16:38:19-08:00
# 23  2020-05-28T07:02:58-07:00
# 24  2022-05-12T01:50:41-07:00
# 25  2019-09-11T14:39:37-07:00
# 26  2020-01-30T07:57:50-08:00
# 27  2020-11-05T07:00:07-08:00
# 28  2019-12-26T06:05:07-08:00
# 29  2018-10-04T14:08:20-07:00
# 30  2020-09-08T12:14:22-07:00
# 31  2022-01-04T08:19:44-08:00
# 32  2019-04-18T09:18:49-07:00
# 33  2020-03-06T07:37:23-08:00
# 34  2019-09-11T14:18:09-07:00
# 35  2022-05-12T01:54:56-07:00
# 36  2019-07-19T07:28:02-07:00
# 37  2017-10-19T15:50:22-07:00
# 38  2018-06-21T14:43:37-07:00
# 39  2022-05-12T01:50:41-07:00
# 40  2020-11-09T19:10:07-08:00
# 41  2020-11-04T21:50:01-08:00
# 42  2023-03-23T06:04:25-07:00
# 43  2019-10-31T07:39:58-07:00
# 44  2022-05-12T01:50:41-07:00
#
#                                           Description  \
# 0   The Democrats' partisan impeachment push is ge...
# 1   President Trump on Wednesday said that Ambassa...
# 2   President Donald Trump will declare a national...
# 3   Sixth in a 10-part weekly series. The Politics...
# 4   WASHINGTON – President Donald Trump faced blow...
# 5   Senate Republicans vulnerable to a Democratic ...
# 6   New allegations of Donald Trump groping women ...
# 7   DAYS AFTER a gunman carried out a horrifying a...
# 8   He again helped Putin cover up Russia’s attack...
# 9   A president who talks and acts tough on trade ...
# 10  Sen. Marsha Blackburn (R-Tenn.) said on Wednes...
# 11  He's a hard-core conservative on everything fr...
# 12  Donald Trump and his attorney general seem hea...
# 13  The president said the White House and congres...
# 14  House Speaker Nancy Pelosi drew criticism Wedn...
# 15  The world got its first glimpse on Sunday into...
# 16  Even as they widely condemn the violence at th...
# 17  In baseball, when a team trades a player to an...
# 18  Former President Donald Trump's legal team wil...
# 19  The Capitol insurrection was based on a lie ab...
# 20  WASHINGTON—President Trump used a “Social Medi...
# 21  The House voted to impeach President Trump for...
# 22  The widespread Republican criticism Tucker Car...
# 23  President Donald Trump is preparing to sign an...
# 24  White House Press Secretary Josh Earnest said ...
# 25  In tweets posted late Saturday night, Presiden...
# 26  WASHINGTON — President Donald Trump’s former n...
# 27  Let’s be real. Goliath was never going to let ...
# 28  Washington (CNN)The House still seeks former W...
# 29  The Trump administration aims to step up trade...
# 30  For Washington staffers and politicos, a day o...
# 31  Alengthy New York Times editorial over the wee...
# 32  Members of President Donald Trump's campaign s...
# 33  YESTERDAY, THE PRESIDENT OF THE UNITED STATES ...
# 34  President Trump said Monday that peace negotia...
# 35  What is William Barr's red line? It's the ques...
# 36  In William Julius Wilson’s 1978 book, “The Dec...
# 37  Israel is wasting no time in trying to transla...
# 38  The policy is real. And Democrats aren’t to bl...
# 39  U.S. President Barack Obama addressed global c...
# 40  U.S. Attorney General William Barr has authori...
# 41  When Donald Trump narrowly won Wisconsin in 20...
# 42  Former President Donald Trump knows his base b...
# 43  The U.S. military raid resulting in the death ...
# 44  President Donald Trump says young undocumented...
#
#                                           Source_Name Source_Bias  \
# 0   RNC 2020: Melania Trump, Mike Pompeo Buck Trad...      Center
# 1   Trump’s big RNC challenge: Reframing pandemic ...      Center
# 2   OPINION: The RNC’s aspirational message couldn...       Right
# 3   ANALYSIS: Like Joe Rogan, The RNC Will Thrive ...       Right
# 4   ANALYSIS: The RNC portrays Trump as he wants t...        Left
# 5      OPINION: What country does Mike Pence live in?        Left
# 6     Trump Continues Virus Fight: 'Maybe I'm Immune'       Right
# 7   OPINION: Cal Thomas: Why Trump's COVID experie...       Right
# 8   President Trump has tested positive for COVID-...   Lean Left
# 9   President Trump has Covid-19: How global media...      Center
# 10  OPINION: Donald Trump Still Doesn’t Care If Yo...        Left
# 11  Trump's Orbit Now Has More New COVID Cases Tha...      Center
# 12  Trump passports taken in FBI search of Mar-a-L...   Lean Left
# 13  FBI's Mar-a-Lago Ransacking Takes Another Irre...       Right
# 14  FBI's sealed evidence that led to search of Tr...      Center
# 15  Graham pushes for release of Trump search affi...   Lean Left
# 16  Trump Still Considering Release of Raid Survei...       Right
# 17  OPINION: 10 Similarities Between The FBI’s Mar...       Right
# 18  FBI, Homeland Security warn about threats to l...   Lean Left
# 19  Clinton to dismiss Trump's economic plan as a ...   Lean Left
# 20  Trump tries to right his campaign, talking of ...   Lean Left
# 21  Trump Team Bets Impeachment Will Backfire on D...      Center
# 22  Investors are betting on a Clinton-like market...      Center
# 23  OPINION: Impeachment is risky, but transcript ...      Center
# 24  Why Pelosi and her party finally embraced impe...   Lean Left
# 25  Trump lashes out at Democrats as whistleblower...   Lean Left
# 26       Trump Is Already Fundraising Off Impeachment        Left
# 27  Intel chief Maguire defends handling of Trump ...       Right
# 28  Transcript of Trump's call with Ukraine shows ...  Lean Right
# 29  Former Romney Advisor Claims 30 Republican Sen...       Right
# 30  OPINION: Sasse, Cruz, and Tillis: Trump's thre...  Lean Right
# 31  A dozen Republican senators show some spine. I...   Lean Left
# 32  Senate Passes Resolution to Block Trump’s Bord...      Center
# 33  12 senators break with President Trump, vote t...   Lean Left
# 34  Senate Republicans revolt against Trump over b...      Center
# 35  In Helsinki, Trump Shows He Is Indeed Guilty o...        Left
# 36  Trump voices support for U.S. intelligence a d...   Lean Left
# 37  Trump critics outdo each other with melodramat...  Lean Right
# 38  OPINION: Connecting Students Across the Partis...   Lean Left
# 39  Trump cancels Kim summit amid North Korea 'hos...      Center
# 40  Why Secretary of State Rex Tillerson was fired...   Lean Left
# 41  Rex Tillerson Gets Fired the Day After He Crit...        Left
# 42  Republican senators slowly begin to accept Bid...   Lean Left
# 43                                democracy prevailed   Lean Left
# 44  McConnell warns GOP off Electoral College braw...   Lean Left
#
#                                       Source_Headline  \
# 0   https://www.allsides.com/news/2019-12-26-0602/...
# 1   https://www.allsides.com/news/2019-11-21-0734/...
# 2   https://www.allsides.com/news/2019-02-14-1633/...
# 3   https://www.allsides.com/news/2016-10-12-0731/...
# 4   https://www.allsides.com/news/2019-09-11-1423/...
# 5   https://www.allsides.com/news/2020-01-16-0722/...
# 6   https://www.allsides.com/news/2016-10-13-0833/...
# 7   https://www.allsides.com/news/2019-03-21-1316/...
# 8   https://www.allsides.com/news/2018-07-19-1511/...
# 9   https://www.allsides.com/news/2019-05-10-0717/...
# 10  https://www.allsides.com/news/2020-01-16-0718/...
# 11  https://www.allsides.com/news/2018-07-12-1251/...
# 12  https://www.allsides.com/news/2020-02-20-0954/...
# 13  https://www.allsides.com/news/2019-01-31-1619/...
# 14  https://www.allsides.com/news/2020-01-16-0707/...
# 15  https://www.allsides.com/news/2019-03-28-1419/...
# 16  https://www.allsides.com/news/2021-01-13-1223/...
# 17  https://www.allsides.com/news/2018-10-04-1415/...
# 18  https://www.allsides.com/news/2022-09-01-0757/...
# 19  https://www.allsides.com/news/2022-01-06-0616/...
# 20  https://www.allsides.com/news/2019-07-12-0603/...
# 21  https://www.allsides.com/news/2021-01-13-1425/...
# 22  https://www.allsides.com/news/2023-03-08-1638/...
# 23  https://www.allsides.com/news/2020-05-28-0702/...
# 24  https://www.allsides.com/news/2016-11-01-1153/...
# 25  https://www.allsides.com/news/2019-09-11-1439/...
# 26  https://www.allsides.com/news/2020-01-30-0757/...
# 27  https://www.allsides.com/news/2020-11-05-0700/...
# 28  https://www.allsides.com/news/2019-12-26-0605/...
# 29  https://www.allsides.com/news/2018-10-04-1408/...
# 30  https://www.allsides.com/news/2020-09-08-1214/...
# 31  https://www.allsides.com/news/2022-01-04-0819/...
# 32  https://www.allsides.com/news/2019-04-18-0918/...
# 33  https://www.allsides.com/news/2019-07-19-1006/...
# 34  https://www.allsides.com/news/2019-09-11-1418/...
# 35  https://www.allsides.com/news/2020-02-20-1012/...
# 36  https://www.allsides.com/news/2019-07-19-0728/...
# 37  https://www.allsides.com/news/2017-10-19-1550/...
# 38  https://www.allsides.com/news/2018-06-21-1443/...
# 39  https://www.allsides.com/news/2016-05-26-1559/...
# 40  https://www.allsides.com/news/2020-11-09-1910/...
# 41  https://www.allsides.com/news/2020-11-04-2150/...
# 42  https://www.allsides.com/news/2023-03-23-0604/...
# 43  https://www.allsides.com/news/2019-10-31-0739/...
# 44  https://www.allsides.com/news/2019-11-14-0636/...
#
#                                           Source_Link
# 0   https://www.allsides.com/news/2019-12-26-0602/...
# 1   https://www.allsides.com/news/2019-11-21-0734/...
# 2   https://www.allsides.com/news/2019-02-14-1633/...
# 3   http://www.allsides.com/news/2016-10-12-0731/p...
# 4   https://www.allsides.com/news/2019-09-11-1423/...
# 5   https://www.allsides.com/news/2020-01-16-0722/...
# 6   http://www.allsides.com/news/2016-10-13-0833/t...
# 7   https://www.allsides.com/news/2019-03-21-1316/...
# 8   https://www.allsides.com/news/2018-07-19-1511/...
# 9   https://www.allsides.com/news/2019-05-10-0717/...
# 10  https://www.allsides.com/news/2020-01-16-0718/...
# 11  https://www.allsides.com/news/2018-07-12-1251/...
# 12  https://www.allsides.com/news/2020-02-20-0954/...
# 13  https://www.allsides.com/news/2019-01-31-1619/...
# 14  https://www.allsides.com/news/2020-01-16-0707/...
# 15  https://www.allsides.com/news/2019-03-28-1419/...
# 16  https://www.allsides.com/news/2021-01-13-1223/...
# 17  https://www.allsides.com/news/2018-10-04-1415/...
# 18  https://www.allsides.com/news/2022-09-01-0757/...
# 19  https://www.allsides.com/news/2022-01-06-0616/...
# 20  https://www.allsides.com/news/2019-07-12-0603/...
# 21  https://www.allsides.com/news/2021-01-13-1425/...
# 22  https://www.allsides.com/news/2023-03-08-1638/...
# 23  https://www.allsides.com/news/2020-05-28-0702/...
# 24  http://www.allsides.com/news/2016-11-01-1153/w...
# 25  https://www.allsides.com/news/2019-09-11-1439/...
# 26  https://www.allsides.com/news/2020-01-30-0757/...
# 27  https://www.allsides.com/news/2020-11-05-0700/...
# 28  https://www.allsides.com/news/2019-12-26-0605/...
# 29  https://www.allsides.com/news/2018-10-04-1408/...
# 30  https://www.allsides.com/news/2020-09-08-1214/...
# 31  https://www.allsides.com/news/2022-01-04-0819/...
# 32  https://www.allsides.com/news/2019-04-18-0918/...
# 33  https://www.allsides.com/news/2019-07-19-1006/...
# 34  https://www.allsides.com/news/2019-09-11-1418/...
# 35  https://www.allsides.com/news/2020-02-20-1012/...
# 36  https://www.allsides.com/news/2019-07-19-0728/...
# 37  http://www.allsides.com/news/2017-10-19-1550/n...
# 38  https://www.allsides.com/news/2018-06-21-1443/...
# 39  http://www.allsides.com/news/2016-05-26-1559/o...
# 40  https://www.allsides.com/news/2020-11-09-1910/...
# 41  https://www.allsides.com/news/2020-11-04-2150/...
# 42  https://www.allsides.com/news/2023-03-23-0604/...
# 43  https://www.allsides.com/news/2019-10-31-0739/...
# 44  https://www.allsides.com/news/2019-11-14-0636/...

# %%
d=pd.read_csv('allsides-content-f.csv')

# %%
# get all news article links

def extract_articles(link):
    for i in range(len(d['Source_Headline'])):
        soup = soup_basics(d['Source_Headline'][i])
        link=None
        # locate relevant information within the extracted page
        substory_list = soup.find_all(class_='read-more-story')

        # loop through the different news sources within each major news story
        try:

          link = re.search('(?P<url>https?://[^\s]+)', str(substory_list)).group('url')
        except: continue
        link = link[:-1]
        d['Source_Link'][i]=link
extract_articles(d.Source_Headline)

# %%
# get all image from article links
d['Image_link']=0

def extract_articles(link):
    for i in range(len(d['Source_Link'])):
        try:
          soup = soup_basics(d['Source_Link'][i])
          link=None 
          # locate relevant information within the extracted page
          story_image = soup.find(property="og:image")

          # loop through the different news sources within each major news story
          

          link = re.search('(?P<url>https?://[^\s]+)', str(story_image)).group('url')
        except: continue
        link = link[:-1]
        d['Image_link'][i]=link
extract_articles(d['Source_Link'])
# Out:
# <ipython-input-14-10c87634e060>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Image_link'][i]=link

# %% [markdown]
# We're showing the first five rows of the CSV we created. So far, everything looks satisfactory.
#
# Keep in mind; this DataFrame lacks specific information for analyzing news articles. Such as the actual body or text of the article (and perhaps the authors of the article). For Part 2, we will be using the same CSV to extract the necessary information.

# %%
d

# %%
file_l = list(d.Source_Link)

# %%
with open('link_file.txt', 'w') as file:
    # iterate over the list and write each string to a new line in the file
    for string in file_l:
        file.write(string + '\n')

# %%
d=d.dropna()

# %%
d.to_csv("allsides-content-f.csv", index=False)
